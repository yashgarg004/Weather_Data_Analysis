# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import seaborn as sns
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
weather_df = pd.read_csv('/content/testset.csv', parse_dates=['datetime_utc'], index_col='datetime_utc')
weather_df.head()
# Out:
#                     _conds  _dewptm  _fog  _hail  _heatindexm  _hum  _precipm  \
# datetime_utc
# 1996-11-01 11:00:00  Smoke      9.0     0      0          NaN  27.0       NaN
# 1996-11-01 12:00:00  Smoke     10.0     0      0          NaN  32.0       NaN
# 1996-11-01 13:00:00  Smoke     11.0     0      0          NaN  44.0       NaN
# 1996-11-01 14:00:00  Smoke     10.0     0      0          NaN  41.0       NaN
# 1996-11-01 16:00:00  Smoke     11.0     0      0          NaN  47.0       NaN
#
#                      _pressurem  _rain  _snow  _tempm  _thunder  _tornado  \
# datetime_utc
# 1996-11-01 11:00:00      1010.0      0      0    30.0         0         0
# 1996-11-01 12:00:00     -9999.0      0      0    28.0         0         0
# 1996-11-01 13:00:00     -9999.0      0      0    24.0         0         0
# 1996-11-01 14:00:00      1010.0      0      0    24.0         0         0
# 1996-11-01 16:00:00      1011.0      0      0    23.0         0         0
#
#                      _vism  _wdird _wdire  _wgustm  _windchillm  _wspdm
# datetime_utc
# 1996-11-01 11:00:00    5.0   280.0   West      NaN          NaN     7.4
# 1996-11-01 12:00:00    NaN     0.0  North      NaN          NaN     NaN
# 1996-11-01 13:00:00    NaN     0.0  North      NaN          NaN     NaN
# 1996-11-01 14:00:00    2.0     0.0  North      NaN          NaN     NaN
# 1996-11-01 16:00:00    1.2     0.0  North      NaN          NaN     0.0

# %%
weather_df = weather_df.loc[:,[' _conds', ' _hum', ' _tempm']]
weather_df = weather_df.rename(index=str, columns={' _conds': 'condition', ' _hum': 'humidity', ' _pressurem': 'pressure', ' _tempm': 'temprature'})
print(f'dataset shape (rows, columns) - {weather_df.shape}')
weather_df.head()
# Out:
# dataset shape (rows, columns) - (100990, 3)
#                     condition  humidity  temprature
# datetime_utc
# 1996-11-01 11:00:00     Smoke      27.0        30.0
# 1996-11-01 12:00:00     Smoke      32.0        28.0
# 1996-11-01 13:00:00     Smoke      44.0        24.0
# 1996-11-01 14:00:00     Smoke      41.0        24.0
# 1996-11-01 16:00:00     Smoke      47.0        23.0

# %%
weather_df.dtypes, weather_df.index.dtype
# Out:
# (condition      object
#  humidity      float64
#  temprature    float64
#  dtype: object,
#  dtype('O'))

# %%
weather_df.index = pd.to_datetime(weather_df.index)
weather_df.index
# Out:
# DatetimeIndex(['1996-11-01 11:00:00', '1996-11-01 12:00:00',
#                '1996-11-01 13:00:00', '1996-11-01 14:00:00',
#                '1996-11-01 16:00:00', '1996-11-01 17:00:00',
#                '1996-11-01 18:00:00', '1996-11-01 19:00:00',
#                '1996-11-01 20:00:00', '1996-11-01 21:00:00',
#                ...
#                '2017-04-23 15:00:00', '2017-04-23 18:00:00',
#                '2017-04-23 21:00:00', '2017-04-24 00:00:00',
#                '2017-04-24 03:00:00', '2017-04-24 06:00:00',
#                '2017-04-24 09:00:00', '2017-04-24 12:00:00',
#                '2017-04-24 15:00:00', '2017-04-24 18:00:00'],
#               dtype='datetime64[ns]', name='datetime_utc', length=100990, freq=None)

# %%
def list_and_visualize_missing_data(dataset):

    total = dataset.isnull().sum().sort_values(ascending=False)
    percent = ((dataset.isnull().sum())/(dataset.isnull().count())).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    missing_data = missing_data[missing_data.Total > 0]

    missing_data.plot.bar(subplots=True, figsize=(16,9))

list_and_visualize_missing_data(weather_df)

# %%
weather_df.ffill(inplace=True)
weather_df[weather_df.isnull()].count()
# Out:
# condition     0
# humidity      0
# temprature    0
# dtype: int64

# %%
weather_df.describe()
# Out:
#             humidity     temprature
# count  100990.000000  100990.000000
# mean       57.957422      25.438222
# std        23.821218       8.487994
# min         4.000000       1.000000
# 25%        39.000000      19.000000
# 50%        59.000000      27.000000
# 75%        78.000000      32.000000
# max       243.000000      90.000000

# %%
weather_df = weather_df[weather_df.temprature < 50]
weather_df = weather_df[weather_df.humidity <= 100]

# %%
weather_condition = (weather_df.condition.value_counts()/(weather_df.condition.value_counts().sum()))*100
weather_condition.plot.bar(figsize=(16,9))
plt.xlabel('Weather Conditions')
plt.ylabel('Percent')
# Out:
# Text(0, 0.5, 'Percent')

# %%
weather_df.plot(subplots=True, figsize=(20,12))
# Out:
# array([<Axes: xlabel='datetime_utc'>, <Axes: xlabel='datetime_utc'>],
#       dtype=object)

# %%
weather_df['2015':'2016'].resample('D').fillna(method='pad').plot(subplots=True, figsize=(20,12))
# Out:
# <ipython-input-13-37068f9d2e1d>:1: FutureWarning: DatetimeIndexResampler.fillna is deprecated and will be removed in a future version. Use obj.ffill(), obj.bfill(), or obj.nearest() instead.
#   weather_df['2015':'2016'].resample('D').fillna(method='pad').plot(subplots=True, figsize=(20,12))
# array([<Axes: xlabel='datetime_utc'>, <Axes: xlabel='datetime_utc'>],
#       dtype=object)

# %%
train_df = weather_df['2000':'2015'].resample('ME').mean().fillna(method='pad')
train_df.drop(columns='humidity', axis=1, inplace=True)
test_df = weather_df['2016':'2017'].resample('ME').mean().fillna(method='pad')
test_df.drop(columns='humidity', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string 'FogFogFogFogFogFogFogSmokeSmokeSmokeSmokeSmokeShallow FogShallow FogFogFogFogFogFogFogFogFogFogFogFogFogFogShallow FogShallow FogShallow FogFogShallow FogSmokeSmokeSmokeSmokeShallow FogFogFogFogFogFogFogFogFogFogFogFogFogFogFogFogSmokeSmokeSmokeSmokeSmokeSmokeShallow FogShallow FogFogFogFogFogFogFogFogFogFogFogFogFogFogSmokeSmokeSmokeSmokeSmokeSmokeSmokeShallow FogShallow FogShallow FogFogFogFogFogFogFogFogFogFogFogFogFogFogFogSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeShallow FogShallow FogShallow FogFogFogFogFogFogFogFogFogShallow FogFogFogFogSmokeSmokeSmokeSmokeSmokePartly CloudyShallow FogShallow FogShallow FogFogFogFogFogFogFogFogFogFogFogFogUnknownFogFogFogSmokeSmokeSmokeSmokeSmokeShallow FogShallow FogFogFogFogFogFogFogFogFogFogFogFogSmokeSmokeSmokeSmokeSmokeMostly CloudyShallow FogShallow FogShallow FogShallow FogShallow FogFogFogFogFogFogFogFogFogFogFogMostly CloudyMostly CloudyShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogFogShallow FogShallow FogMostly CloudyShallow FogShallow FogSmokeSmokeSmokeSmokeSmokeShallow FogShallow FogShallow FogMostly CloudyShallow FogShallow FogShallow FogShallow FogShallow FogShallow FogScattered CloudsScattered CloudsClearScattered CloudsShallow FogShallow FogShallow FogShallow FogSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeS...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b63bf147ece0> in <cell line: 0>()
# ----> 1 train_df = weather_df['2000':'2015'].resample('ME').mean().fillna(method='pad')
#       2 train_df.drop(columns='humidity', axis=1, inplace=True)
#       3 test_df = weather_df['2016':'2017'].resample('ME').mean().fillna(method='pad')
#       4 test_df.drop(columns='humidity', axis=1, inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/resample.py in mean(self, numeric_only, *args, **kwargs)
#    1382         maybe_warn_args_and_kwargs(type(self), "mean", args, kwargs)
#    1383         nv.validate_resampler_func("mean", args, kwargs)
# -> 1384         return self._downsample("mean", numeric_only=numeric_only)
#    1385
#    1386     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/resample.py in _downsample(self, how, **kwargs)
#    1780         # we want to call the actual grouper method here
#    1781         if self.axis == 0:
# -> 1782             result = obj.groupby(self._grouper).aggregate(how, **kwargs)
#    1783         else:
#    1784             # test_resample_axis1
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1430
#    1431         op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432         result = op.agg()
#    1433         if not is_dict_like(func) and result is not None:
#    1434             # GH #52849
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in agg(self)
#     185
#     186         if isinstance(func, str):
# --> 187             return self.apply_str()
#     188
#     189         if is_dict_like(func):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_str(self)
#     601                 else:
#     602                     self.kwargs["axis"] = self.axis
# --> 603         return self._apply_str(obj, func, *self.args, **self.kwargs)
#     604
#     605     def apply_list_or_dict_like(self) -> DataFrame | Series:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in _apply_str(self, obj, func, *args, **kwargs)
#     691             f = getattr(obj, func)
#     692             if callable(f):
# --> 693                 return f(*args, **kwargs)
#     694
#     695             # people may aggregate on a non-callable attribute
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
def plot_rolling_mean_std(ts):
    rolling_mean = ts.rolling(12).mean()
    rolling_std = ts.rolling(12).std()
    plt.figure(figsize=(22,10))

    plt.plot(ts, label='Actual Mean')
    plt.plot(rolling_mean, label='Rolling Mean')
    plt.plot(rolling_std, label = 'Rolling Std')
    plt.xlabel("Date")
    plt.ylabel("Mean Temperature")
    plt.title('Rolling Mean & Rolling Standard Deviation')
    plt.legend()
    plt.show()

# %%
def perform_dickey_fuller_test(ts):
    result = adfuller(ts, autolag='AIC')
    print('Test statistic: ' , result[0])
    print('Critical Values:' ,result[4])
